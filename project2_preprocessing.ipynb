# %%
from google.colab import drive
import os
import numpy as np
from scipy import ndimage
from PIL import Image
from tifffile import imsave

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
input_path_pd = '/content/drive/MyDrive/parkisons_disease/PD'
input_path_normal = '/content/drive/MyDrive/parkisons_disease/Normal'

# %%
output_path = '/content/drive/MyDrive/preprocessed_images'

os.makedirs(output_path, exist_ok=True)

# %%
output_format = "PNG"

# %%
# Preprocess images from PD folder
for i in range(1, 907):
    filename = f'PD_{i}.png'
    input_image = Image.open(os.path.join(input_path_pd, filename)).convert('L')

    image_array = np.asarray(input_image)

    if np.std(image_array) == 0:
        print(f"Warning: Standard deviation of image {filename} is 0, skipping normalization.")
        continue

    image_array = (image_array - image_array.mean()) / np.std(image_array)

    resized_image = ndimage.zoom(image_array, (0.5, 0.5), mode='constant', order=1)
    blurred_image = ndimage.gaussian_filter(resized_image, sigma=1)

    if output_format == "PNG":
        scaled_image = (blurred_image * 255).astype(np.uint8)
        preprocessed_image = Image.fromarray(scaled_image)
        preprocessed_image.save(os.path.join(output_path, filename))
    elif output_format == "TIFF":
        imsave(os.path.join(output_path, filename), blurred_image.astype(np.float32))
    else:
        print(f"Invalid output format specified: {output_format}. Please choose 'PNG' or 'TIFF'.")

    print(f"Preprocessed image {filename} saved successfully from PD folder!")
# Out:
# Preprocessed image PD_1.png saved successfully from PD folder!
# Preprocessed image PD_2.png saved successfully from PD folder!
# Preprocessed image PD_3.png saved successfully from PD folder!
# Preprocessed image PD_4.png saved successfully from PD folder!
# Preprocessed image PD_5.png saved successfully from PD folder!
# Preprocessed image PD_6.png saved successfully from PD folder!
# Preprocessed image PD_7.png saved successfully from PD folder!
# Preprocessed image PD_8.png saved successfully from PD folder!
# Preprocessed image PD_9.png saved successfully from PD folder!
# Preprocessed image PD_10.png saved successfully from PD folder!
# Preprocessed image PD_11.png saved successfully from PD folder!
# Preprocessed image PD_12.png saved successfully from PD folder!
# Preprocessed image PD_13.png saved successfully from PD folder!
# Preprocessed image PD_14.png saved successfully from PD folder!
# Preprocessed image PD_15.png saved successfully from PD folder!
# Preprocessed image PD_16.png saved successfully from PD folder!
# Preprocessed image PD_17.png saved successfully from PD folder!
# Preprocessed image PD_18.png saved successfully from PD folder!
# Preprocessed image PD_19.png saved successfully from PD folder!
# Preprocessed image PD_20.png saved successfully from PD folder!
# Preprocessed image PD_21.png saved successfully from PD folder!
# Preprocessed image PD_22.png saved successfully from PD folder!
# Preprocessed image PD_23.png saved successfully from PD folder!
# Preprocessed image PD_24.png saved successfully from PD folder!
# Preprocessed image PD_25.png saved successfully from PD folder!
# Preprocessed image PD_26.png saved successfully from PD folder!
# Preprocessed image PD_27.png saved successfully from PD folder!
# Preprocessed image PD_28.png saved successfully from PD folder!
# Preprocessed image PD_29.png saved successfully from PD folder!
# Preprocessed image PD_30.png saved successfully from PD folder!
# Preprocessed image PD_31.png saved successfully from PD folder!
# Preprocessed image PD_32.png saved successfully from PD folder!
# Preprocessed image PD_33.png saved successfully from PD folder!
# Preprocessed image PD_34.png saved successfully from PD folder!
# Preprocessed image PD_35.png saved successfully from PD folder!
# Preprocessed image PD_36.png saved successfully from PD folder!
# Preprocessed image PD_37.png saved successfully from PD folder!
# Preprocessed image PD_38.png saved successfully from PD folder!
# Preprocessed image PD_39.png saved successfully from PD folder!
# Preprocessed image PD_40.png saved successfully from PD folder!
# Preprocessed image PD_41.png saved successfully from PD folder!
# Preprocessed image PD_42.png saved successfully from PD folder!
# Preprocessed image PD_43.png saved successfully from PD folder!
# Preprocessed image PD_44.png saved successfully from PD folder!
# Preprocessed image PD_45.png saved successfully from PD folder!
# Preprocessed image PD_46.png saved successfully from PD folder!
# Preprocessed image PD_47.png saved successfully from PD folder!
# Preprocessed image PD_48.png saved successfully from PD folder!
# Preprocessed image PD_49.png saved successfully from PD folder!
# Preprocessed image PD_50.png saved successfully from PD folder!
# Preprocessed image PD_51.png saved successfully from PD folder!
# Preprocessed image PD_52.png saved successfully from PD folder!
# Preprocessed image PD_53.png saved successfully from PD folder!
# Preprocessed image PD_54.png saved successfully from PD folder!
# Preprocessed image PD_55.png saved successfully from PD folder!
# Preprocessed image PD_56.png saved successfully from PD folder!
# Preprocessed image PD_57.png saved successfully from PD folder!
# Preprocessed image PD_58.png saved successfully from PD folder!
# Preprocessed image PD_59.png saved successfully from PD folder!
# Preprocessed image PD_60.png saved successfully from PD folder!
# Preprocessed image PD_61.png saved successfully from PD folder!
# Preprocessed image PD_62.png saved successfully from PD folder!
# Preprocessed image PD_63.png saved successfully from PD folder!
# Preprocessed image PD_64.png saved successfully from PD folder!
# Preprocessed image PD_65.png saved successfully from PD folder!
# Preprocessed image PD_66.png saved successfully from PD folder!
# Preprocessed image PD_67.png saved successfully from PD folder!
# Preprocessed image PD_68.png saved successfully from PD folder!
# Preprocessed image PD_69.png saved successfully from PD folder!
# Preprocessed image PD_70.png saved successfully from PD folder!
# Preprocessed image PD_71.png saved successfully from PD folder!
# Preprocessed image PD_72.png saved successfully from PD folder!
# Preprocessed image PD_73.png saved successfully from PD folder!
# Preprocessed image PD_74.png saved successfully from PD folder!
# Preprocessed image PD_75.png saved successfully from PD folder!
# Preprocessed image PD_76.png saved successfully from PD folder!
# Preprocessed image PD_77.png saved successfully from PD folder!
# Preprocessed image PD_78.png saved successfully from PD folder!
# Preprocessed image PD_79.png saved successfully from PD folder!
# Preprocessed image PD_80.png saved successfully from PD folder!
# Preprocessed image PD_81.png saved successfully from PD folder!
# Preprocessed image PD_82.png saved successfully from PD folder!
# Preprocessed image PD_83.png saved successfully from PD folder!
# Preprocessed image PD_84.png saved successfully from PD folder!
# Preprocessed image PD_85.png saved successfully from PD folder!
# Preprocessed image PD_86.png saved successfully from PD folder!
# Preprocessed image PD_87.png saved successfully from PD folder!
# Preprocessed image PD_88.png saved successfully from PD folder!
# Preprocessed image PD_89.png saved successfully from PD folder!
# Preprocessed image PD_90.png saved successfully from PD folder!
# Preprocessed image PD_91.png saved successfully from PD folder!
# Preprocessed image PD_92.png saved successfully from PD folder!
# Preprocessed image PD_93.png saved successfully from PD folder!
# Preprocessed image PD_94.png saved successfully from PD folder!
# Preprocessed image PD_95.png saved successfully from PD folder!
# Preprocessed image PD_96.png saved successfully from PD folder!
# Preprocessed image PD_97.png saved successfully from PD folder!
# Preprocessed image PD_98.png saved successfully from PD folder!
# Preprocessed image PD_99.png saved successfully from PD folder!
# Preprocessed image PD_100.png saved successfully from PD folder!
# Preprocessed image PD_101.png saved successfully from PD folder!
# Preprocessed image PD_102.png saved successfully from PD folder!
# Preprocessed image PD_103.png saved successfully from PD folder!
# Preprocessed image PD_104.png saved successfully from PD folder!
# Preprocessed image PD_105.png saved successfully from PD folder!
# Preprocessed image PD_106.png saved successfully from PD folder!
# Preprocessed image PD_107.png saved successfully from PD folder!
# Preprocessed image PD_108.png saved successfully from PD folder!
# Preprocessed image PD_109.png saved successfully from PD folder!
# Preprocessed image PD_110.png saved successfully from PD folder!
# Preprocessed image PD_111.png saved successfully from PD folder!
# Preprocessed image PD_112.png saved successfully from PD folder!
# Preprocessed image PD_113.png saved successfully from PD folder!
# Preprocessed image PD_114.png saved successfully from PD folder!
# Preprocessed image PD_115.png saved successfully from PD folder!
# Preprocessed image PD_116.png saved successfully from PD folder!
# Preprocessed image PD_117.png saved successfully from PD folder!
# Preprocessed image PD_118.png saved successfully from PD folder!
# Preprocessed image PD_119.png saved successfully from PD folder!
# Preprocessed image PD_120.png saved successfully from PD folder!
# Preprocessed image PD_121.png saved successfully from PD folder!
# Preprocessed image PD_122.png saved successfully from PD folder!
# Preprocessed image PD_123.png saved successfully from PD folder!
# Preprocessed image PD_124.png saved successfully from PD folder!
# Preprocessed image PD_125.png saved successfully from PD folder!
# Preprocessed image PD_126.png saved successfully from PD folder!
# Preprocessed image PD_127.png saved successfully from PD folder!
# Preprocessed image PD_128.png saved successfully from PD folder!
# Preprocessed image PD_129.png saved successfully from PD folder!
# Preprocessed image PD_130.png saved successfully from PD folder!
# Preprocessed image PD_131.png saved successfully from PD folder!
# Preprocessed image PD_132.png saved successfully from PD folder!
# Preprocessed image PD_133.png saved successfully from PD folder!
# Preprocessed image PD_134.png saved successfully from PD folder!
# Preprocessed image PD_135.png saved successfully from PD folder!
# Preprocessed image PD_136.png saved successfully from PD folder!
# Preprocessed image PD_137.png saved successfully from PD folder!
# Preprocessed image PD_138.png saved successfully from PD folder!
# Preprocessed image PD_139.png saved successfully from PD folder!
# Preprocessed image PD_140.png saved successfully from PD folder!
# Preprocessed image PD_141.png saved successfully from PD folder!
# Preprocessed image PD_142.png saved successfully from PD folder!
# Preprocessed image PD_143.png saved successfully from PD folder!
# Preprocessed image PD_144.png saved successfully from PD folder!
# Preprocessed image PD_145.png saved successfully from PD folder!
# Preprocessed image PD_146.png saved successfully from PD folder!
# Preprocessed image PD_147.png saved successfully from PD folder!
# Preprocessed image PD_148.png saved successfully from PD folder!
# Preprocessed image PD_149.png saved successfully from PD folder!
# Preprocessed image PD_150.png saved successfully from PD folder!
# Preprocessed image PD_151.png saved successfully from PD folder!
# Preprocessed image PD_152.png saved successfully from PD folder!
# Preprocessed image PD_153.png saved successfully from PD folder!
# Preprocessed image PD_154.png saved successfully from PD folder!
# Preprocessed image PD_155.png saved successfully from PD folder!
# Preprocessed image PD_156.png saved successfully from PD folder!
# Preprocessed image PD_157.png saved successfully from PD folder!
# Preprocessed image PD_158.png saved successfully from PD folder!
# Preprocessed image PD_159.png saved successfully from PD folder!
# Preprocessed image PD_160.png saved successfully from PD folder!
# Preprocessed image PD_161.png saved successfully from PD folder!
# Preprocessed image PD_162.png saved successfully from PD folder!
# Preprocessed image PD_163.png saved successfully from PD folder!
# Preprocessed image PD_164.png saved successfully from PD folder!
# Preprocessed image PD_165.png saved successfully from PD folder!
# Preprocessed image PD_166.png saved successfully from PD folder!
# Preprocessed image PD_167.png saved successfully from PD folder!
# Preprocessed image PD_168.png saved successfully from PD folder!
# Preprocessed image PD_169.png saved successfully from PD folder!
# Preprocessed image PD_170.png saved successfully from PD folder!
# Preprocessed image PD_171.png saved successfully from PD folder!
# Preprocessed image PD_172.png saved successfully from PD folder!
# Preprocessed image PD_173.png saved successfully from PD folder!
# Preprocessed image PD_174.png saved successfully from PD folder!
# Preprocessed image PD_175.png saved successfully from PD folder!
# Preprocessed image PD_176.png saved successfully from PD folder!
# Preprocessed image PD_177.png saved successfully from PD folder!
# Preprocessed image PD_178.png saved successfully from PD folder!
# Preprocessed image PD_179.png saved successfully from PD folder!
# Preprocessed image PD_180.png saved successfully from PD folder!
# Preprocessed image PD_181.png saved successfully from PD folder!
# Preprocessed image PD_182.png saved successfully from PD folder!
# Preprocessed image PD_183.png saved successfully from PD folder!
# Preprocessed image PD_184.png saved successfully from PD folder!
# Preprocessed image PD_185.png saved successfully from PD folder!
# Preprocessed image PD_186.png saved successfully from PD folder!
# Preprocessed image PD_187.png saved successfully from PD folder!
# Preprocessed image PD_188.png saved successfully from PD folder!
# Preprocessed image PD_189.png saved successfully from PD folder!
# Preprocessed image PD_190.png saved successfully from PD folder!
# Preprocessed image PD_191.png saved successfully from PD folder!
# Preprocessed image PD_192.png saved successfully from PD folder!
# Preprocessed image PD_193.png saved successfully from PD folder!
# Preprocessed image PD_194.png saved successfully from PD folder!
# Preprocessed image PD_195.png saved successfully from PD folder!
# Preprocessed image PD_196.png saved successfully from PD folder!
# Preprocessed image PD_197.png saved successfully from PD folder!
# Preprocessed image PD_198.png saved successfully from PD folder!
# Preprocessed image PD_199.png saved successfully from PD folder!
# Preprocessed image PD_200.png saved successfully from PD folder!
# Preprocessed image PD_201.png saved successfully from PD folder!
# Preprocessed image PD_202.png saved successfully from PD folder!
# Preprocessed image PD_203.png saved successfully from PD folder!
# Preprocessed image PD_204.png saved successfully from PD folder!
# Preprocessed image PD_205.png saved successfully from PD folder!
# Preprocessed image PD_206.png saved successfully from PD folder!
# Preprocessed image PD_207.png saved successfully from PD folder!
# Preprocessed image PD_208.png saved successfully from PD folder!
# Preprocessed image PD_209.png saved successfully from PD folder!
# Preprocessed image PD_210.png saved successfully from PD folder!
# Preprocessed image PD_211.png saved successfully from PD folder!
# Preprocessed image PD_212.png saved successfully from PD folder!
# Preprocessed image PD_213.png saved successfully from PD folder!
# Preprocessed image PD_214.png saved successfully from PD folder!
# Preprocessed image PD_215.png saved successfully from PD folder!
# Preprocessed image PD_216.png saved successfully from PD folder!
# Preprocessed image PD_217.png saved successfully from PD folder!
# Preprocessed image PD_218.png saved successfully from PD folder!
# Preprocessed image PD_219.png saved successfully from PD folder!
# Preprocessed image PD_220.png saved successfully from PD folder!
# Preprocessed image PD_221.png saved successfully from PD folder!
# Preprocessed image PD_222.png saved successfully from PD folder!
# Preprocessed image PD_223.png saved successfully from PD folder!
# Preprocessed image PD_224.png saved successfully from PD folder!
# Preprocessed image PD_225.png saved successfully from PD folder!
# Preprocessed image PD_226.png saved successfully from PD folder!
# Preprocessed image PD_227.png saved successfully from PD folder!
# Preprocessed image PD_228.png saved successfully from PD folder!
# Preprocessed image PD_229.png saved successfully from PD folder!
# Preprocessed image PD_230.png saved successfully from PD folder!
# Preprocessed image PD_231.png saved successfully from PD folder!
# Preprocessed image PD_232.png saved successfully from PD folder!
# Preprocessed image PD_233.png saved successfully from PD folder!
# Preprocessed image PD_234.png saved successfully from PD folder!
# Preprocessed image PD_235.png saved successfully from PD folder!
# Preprocessed image PD_236.png saved successfully from PD folder!
# Preprocessed image PD_237.png saved successfully from PD folder!
# Preprocessed image PD_238.png saved successfully from PD folder!
# Preprocessed image PD_239.png saved successfully from PD folder!
# Preprocessed image PD_240.png saved successfully from PD folder!
# Preprocessed image PD_241.png saved successfully from PD folder!
# Preprocessed image PD_242.png saved successfully from PD folder!
# Preprocessed image PD_243.png saved successfully from PD folder!
# Preprocessed image PD_244.png saved successfully from PD folder!
# Preprocessed image PD_245.png saved successfully from PD folder!
# Preprocessed image PD_246.png saved successfully from PD folder!
# Preprocessed image PD_247.png saved successfully from PD folder!
# Preprocessed image PD_248.png saved successfully from PD folder!
# Preprocessed image PD_249.png saved successfully from PD folder!
# Preprocessed image PD_250.png saved successfully from PD folder!
# Preprocessed image PD_251.png saved successfully from PD folder!
# Preprocessed image PD_252.png saved successfully from PD folder!
# Preprocessed image PD_253.png saved successfully from PD folder!
# Preprocessed image PD_254.png saved successfully from PD folder!
# Preprocessed image PD_255.png saved successfully from PD folder!
# Preprocessed image PD_256.png saved successfully from PD folder!
# Preprocessed image PD_257.png saved successfully from PD folder!
# Preprocessed image PD_258.png saved successfully from PD folder!
# Preprocessed image PD_259.png saved successfully from PD folder!
# Preprocessed image PD_260.png saved successfully from PD folder!
# Preprocessed image PD_261.png saved successfully from PD folder!
# Preprocessed image PD_262.png saved successfully from PD folder!
# Preprocessed image PD_263.png saved successfully from PD folder!
# Preprocessed image PD_264.png saved successfully from PD folder!
# Preprocessed image PD_265.png saved successfully from PD folder!
# Preprocessed image PD_266.png saved successfully from PD folder!
# Preprocessed image PD_267.png saved successfully from PD folder!
# Preprocessed image PD_268.png saved successfully from PD folder!
# Preprocessed image PD_269.png saved successfully from PD folder!
# Preprocessed image PD_270.png saved successfully from PD folder!
# Preprocessed image PD_271.png saved successfully from PD folder!
# Preprocessed image PD_272.png saved successfully from PD folder!
# Preprocessed image PD_273.png saved successfully from PD folder!
# Preprocessed image PD_274.png saved successfully from PD folder!
# Preprocessed image PD_275.png saved successfully from PD folder!
# Preprocessed image PD_276.png saved successfully from PD folder!
# Preprocessed image PD_277.png saved successfully from PD folder!
# Preprocessed image PD_278.png saved successfully from PD folder!
# Preprocessed image PD_279.png saved successfully from PD folder!
# Preprocessed image PD_280.png saved successfully from PD folder!
# Preprocessed image PD_281.png saved successfully from PD folder!
# Preprocessed image PD_282.png saved successfully from PD folder!
# Preprocessed image PD_283.png saved successfully from PD folder!
# Preprocessed image PD_284.png saved successfully from PD folder!
# Preprocessed image PD_285.png saved successfully from PD folder!
# Preprocessed image PD_286.png saved successfully from PD folder!
# Preprocessed image PD_287.png saved successfully from PD folder!
# Preprocessed image PD_288.png saved successfully from PD folder!
# Preprocessed image PD_289.png saved successfully from PD folder!
# Preprocessed image PD_290.png saved successfully from PD folder!
# Preprocessed image PD_291.png saved successfully from PD folder!
# Preprocessed image PD_292.png saved successfully from PD folder!
# Preprocessed image PD_293.png saved successfully from PD folder!
# Preprocessed image PD_294.png saved successfully from PD folder!
# Preprocessed image PD_295.png saved successfully from PD folder!
# Preprocessed image PD_296.png saved successfully from PD folder!
# Preprocessed image PD_297.png saved successfully from PD folder!
# Preprocessed image PD_298.png saved successfully from PD folder!
# Preprocessed image PD_299.png saved successfully from PD folder!
# Preprocessed image PD_300.png saved successfully from PD folder!
# Preprocessed image PD_301.png saved successfully from PD folder!
# Preprocessed image PD_302.png saved successfully from PD folder!
# Preprocessed image PD_303.png saved successfully from PD folder!
# Preprocessed image PD_304.png saved successfully from PD folder!
# Preprocessed image PD_305.png saved successfully from PD folder!
# Preprocessed image PD_306.png saved successfully from PD folder!
# Preprocessed image PD_307.png saved successfully from PD folder!
# Preprocessed image PD_308.png saved successfully from PD folder!
# Preprocessed image PD_309.png saved successfully from PD folder!
# Preprocessed image PD_310.png saved successfully from PD folder!
# Preprocessed image PD_311.png saved successfully from PD folder!
# Preprocessed image PD_312.png saved successfully from PD folder!
# Preprocessed image PD_313.png saved successfully from PD folder!
# Preprocessed image PD_314.png saved successfully from PD folder!
# Preprocessed image PD_315.png saved successfully from PD folder!
# Preprocessed image PD_316.png saved successfully from PD folder!
# Preprocessed image PD_317.png saved successfully from PD folder!
# Preprocessed image PD_318.png saved successfully from PD folder!
# Preprocessed image PD_319.png saved successfully from PD folder!
# Preprocessed image PD_320.png saved successfully from PD folder!
# Preprocessed image PD_321.png saved successfully from PD folder!
# Preprocessed image PD_322.png saved successfully from PD folder!
# Preprocessed image PD_323.png saved successfully from PD folder!
# Preprocessed image PD_324.png saved successfully from PD folder!
# Preprocessed image PD_325.png saved successfully from PD folder!
# Preprocessed image PD_326.png saved successfully from PD folder!
# Preprocessed image PD_327.png saved successfully from PD folder!
# Preprocessed image PD_328.png saved successfully from PD folder!
# Preprocessed image PD_329.png saved successfully from PD folder!
# Preprocessed image PD_330.png saved successfully from PD folder!
# Preprocessed image PD_331.png saved successfully from PD folder!
# Preprocessed image PD_332.png saved successfully from PD folder!
# Preprocessed image PD_333.png saved successfully from PD folder!
# Preprocessed image PD_334.png saved successfully from PD folder!
# Preprocessed image PD_335.png saved successfully from PD folder!
# Preprocessed image PD_336.png saved successfully from PD folder!
# Preprocessed image PD_337.png saved successfully from PD folder!
# Preprocessed image PD_338.png saved successfully from PD folder!
# Preprocessed image PD_339.png saved successfully from PD folder!
# Preprocessed image PD_340.png saved successfully from PD folder!
# Preprocessed image PD_341.png saved successfully from PD folder!
# Preprocessed image PD_342.png saved successfully from PD folder!
# Preprocessed image PD_343.png saved successfully from PD folder!
# Preprocessed image PD_344.png saved successfully from PD folder!
# Preprocessed image PD_345.png saved successfully from PD folder!
# Preprocessed image PD_346.png saved successfully from PD folder!
# Preprocessed image PD_347.png saved successfully from PD folder!
# Preprocessed image PD_348.png saved successfully from PD folder!
# Preprocessed image PD_349.png saved successfully from PD folder!
# Preprocessed image PD_350.png saved successfully from PD folder!
# Preprocessed image PD_351.png saved successfully from PD folder!
# Preprocessed image PD_352.png saved successfully from PD folder!
# Preprocessed image PD_353.png saved successfully from PD folder!
# Preprocessed image PD_354.png saved successfully from PD folder!
# Preprocessed image PD_355.png saved successfully from PD folder!
# Preprocessed image PD_356.png saved successfully from PD folder!
# Preprocessed image PD_357.png saved successfully from PD folder!
# Preprocessed image PD_358.png saved successfully from PD folder!
# Preprocessed image PD_359.png saved successfully from PD folder!
# Preprocessed image PD_360.png saved successfully from PD folder!
# Preprocessed image PD_361.png saved successfully from PD folder!
# Preprocessed image PD_362.png saved successfully from PD folder!
# Preprocessed image PD_363.png saved successfully from PD folder!
# Preprocessed image PD_364.png saved successfully from PD folder!
# Preprocessed image PD_365.png saved successfully from PD folder!
# Preprocessed image PD_366.png saved successfully from PD folder!
# Preprocessed image PD_367.png saved successfully from PD folder!
# Preprocessed image PD_368.png saved successfully from PD folder!
# Preprocessed image PD_369.png saved successfully from PD folder!
# Preprocessed image PD_370.png saved successfully from PD folder!
# Preprocessed image PD_371.png saved successfully from PD folder!
# Preprocessed image PD_372.png saved successfully from PD folder!
# Preprocessed image PD_373.png saved successfully from PD folder!
# Preprocessed image PD_374.png saved successfully from PD folder!
# Preprocessed image PD_375.png saved successfully from PD folder!
# Preprocessed image PD_376.png saved successfully from PD folder!
# Preprocessed image PD_377.png saved successfully from PD folder!
# Preprocessed image PD_378.png saved successfully from PD folder!
# Preprocessed image PD_379.png saved successfully from PD folder!
# Preprocessed image PD_380.png saved successfully from PD folder!
# Preprocessed image PD_381.png saved successfully from PD folder!
# Preprocessed image PD_382.png saved successfully from PD folder!
# Preprocessed image PD_383.png saved successfully from PD folder!
# Preprocessed image PD_384.png saved successfully from PD folder!
# Preprocessed image PD_385.png saved successfully from PD folder!
# Preprocessed image PD_386.png saved successfully from PD folder!
# Preprocessed image PD_387.png saved successfully from PD folder!
# Preprocessed image PD_388.png saved successfully from PD folder!
# Preprocessed image PD_389.png saved successfully from PD folder!
# Preprocessed image PD_390.png saved successfully from PD folder!
# Preprocessed image PD_391.png saved successfully from PD folder!
# Preprocessed image PD_392.png saved successfully from PD folder!
# Preprocessed image PD_393.png saved successfully from PD folder!
# Preprocessed image PD_394.png saved successfully from PD folder!
# Preprocessed image PD_395.png saved successfully from PD folder!
# Preprocessed image PD_396.png saved successfully from PD folder!
# Preprocessed image PD_397.png saved successfully from PD folder!
# Preprocessed image PD_398.png saved successfully from PD folder!
# Preprocessed image PD_399.png saved successfully from PD folder!
# Preprocessed image PD_400.png saved successfully from PD folder!
# Preprocessed image PD_401.png saved successfully from PD folder!
# Preprocessed image PD_402.png saved successfully from PD folder!
# Preprocessed image PD_403.png saved successfully from PD folder!
# Preprocessed image PD_404.png saved successfully from PD folder!
# Preprocessed image PD_405.png saved successfully from PD folder!
# Preprocessed image PD_406.png saved successfully from PD folder!
# Preprocessed image PD_407.png saved successfully from PD folder!
# Preprocessed image PD_408.png saved successfully from PD folder!
# Preprocessed image PD_409.png saved successfully from PD folder!
# Preprocessed image PD_410.png saved successfully from PD folder!
# Preprocessed image PD_411.png saved successfully from PD folder!
# Preprocessed image PD_412.png saved successfully from PD folder!
# Preprocessed image PD_413.png saved successfully from PD folder!
# Preprocessed image PD_414.png saved successfully from PD folder!
# Preprocessed image PD_415.png saved successfully from PD folder!
# Preprocessed image PD_416.png saved successfully from PD folder!
# Preprocessed image PD_417.png saved successfully from PD folder!
# Preprocessed image PD_418.png saved successfully from PD folder!
# Preprocessed image PD_419.png saved successfully from PD folder!
# Preprocessed image PD_420.png saved successfully from PD folder!
# Preprocessed image PD_421.png saved successfully from PD folder!
# Preprocessed image PD_422.png saved successfully from PD folder!
# Preprocessed image PD_423.png saved successfully from PD folder!
# Preprocessed image PD_424.png saved successfully from PD folder!
# Preprocessed image PD_425.png saved successfully from PD folder!
# Preprocessed image PD_426.png saved successfully from PD folder!
# Preprocessed image PD_427.png saved successfully from PD folder!
# Preprocessed image PD_428.png saved successfully from PD folder!
# Preprocessed image PD_429.png saved successfully from PD folder!
# Preprocessed image PD_430.png saved successfully from PD folder!
# Preprocessed image PD_431.png saved successfully from PD folder!
# Preprocessed image PD_432.png saved successfully from PD folder!
# Preprocessed image PD_433.png saved successfully from PD folder!
# Preprocessed image PD_434.png saved successfully from PD folder!
# Preprocessed image PD_435.png saved successfully from PD folder!
# Preprocessed image PD_436.png saved successfully from PD folder!
# Preprocessed image PD_437.png saved successfully from PD folder!
# Preprocessed image PD_438.png saved successfully from PD folder!
# Preprocessed image PD_439.png saved successfully from PD folder!
# Preprocessed image PD_440.png saved successfully from PD folder!
# Preprocessed image PD_441.png saved successfully from PD folder!
# Preprocessed image PD_442.png saved successfully from PD folder!
# Preprocessed image PD_443.png saved successfully from PD folder!
# Preprocessed image PD_444.png saved successfully from PD folder!
# Preprocessed image PD_445.png saved successfully from PD folder!
# Preprocessed image PD_446.png saved successfully from PD folder!
# Preprocessed image PD_447.png saved successfully from PD folder!
# Preprocessed image PD_448.png saved successfully from PD folder!
# Preprocessed image PD_449.png saved successfully from PD folder!
# Preprocessed image PD_450.png saved successfully from PD folder!
# Preprocessed image PD_451.png saved successfully from PD folder!
# Preprocessed image PD_452.png saved successfully from PD folder!
# Preprocessed image PD_453.png saved successfully from PD folder!
# Preprocessed image PD_454.png saved successfully from PD folder!
# Preprocessed image PD_455.png saved successfully from PD folder!
# Preprocessed image PD_456.png saved successfully from PD folder!
# Preprocessed image PD_457.png saved successfully from PD folder!
# Preprocessed image PD_458.png saved successfully from PD folder!
# Preprocessed image PD_459.png saved successfully from PD folder!
# Preprocessed image PD_460.png saved successfully from PD folder!
# Preprocessed image PD_461.png saved successfully from PD folder!
# Preprocessed image PD_462.png saved successfully from PD folder!
# Preprocessed image PD_463.png saved successfully from PD folder!
# Preprocessed image PD_464.png saved successfully from PD folder!
# Preprocessed image PD_465.png saved successfully from PD folder!
# Preprocessed image PD_466.png saved successfully from PD folder!
# Preprocessed image PD_467.png saved successfully from PD folder!
# Preprocessed image PD_468.png saved successfully from PD folder!
# Preprocessed image PD_469.png saved successfully from PD folder!
# Preprocessed image PD_470.png saved successfully from PD folder!
# Preprocessed image PD_471.png saved successfully from PD folder!
# Preprocessed image PD_472.png saved successfully from PD folder!
# Preprocessed image PD_473.png saved successfully from PD folder!
# Preprocessed image PD_474.png saved successfully from PD folder!
# Preprocessed image PD_475.png saved successfully from PD folder!
# Preprocessed image PD_476.png saved successfully from PD folder!
# Preprocessed image PD_477.png saved successfully from PD folder!
# Preprocessed image PD_478.png saved successfully from PD folder!
# Preprocessed image PD_479.png saved successfully from PD folder!
# Preprocessed image PD_480.png saved successfully from PD folder!
# Preprocessed image PD_481.png saved successfully from PD folder!
# Preprocessed image PD_482.png saved successfully from PD folder!
# Preprocessed image PD_483.png saved successfully from PD folder!
# Preprocessed image PD_484.png saved successfully from PD folder!
# Preprocessed image PD_485.png saved successfully from PD folder!
# Preprocessed image PD_486.png saved successfully from PD folder!
# Preprocessed image PD_487.png saved successfully from PD folder!
# Preprocessed image PD_488.png saved successfully from PD folder!
# Preprocessed image PD_489.png saved successfully from PD folder!
# Preprocessed image PD_490.png saved successfully from PD folder!
# Preprocessed image PD_491.png saved successfully from PD folder!
# Preprocessed image PD_492.png saved successfully from PD folder!
# Preprocessed image PD_493.png saved successfully from PD folder!
# Preprocessed image PD_494.png saved successfully from PD folder!
# Preprocessed image PD_495.png saved successfully from PD folder!
# Preprocessed image PD_496.png saved successfully from PD folder!
# Preprocessed image PD_497.png saved successfully from PD folder!
# Preprocessed image PD_498.png saved successfully from PD folder!
# Preprocessed image PD_499.png saved successfully from PD folder!
# Preprocessed image PD_500.png saved successfully from PD folder!
# Preprocessed image PD_501.png saved successfully from PD folder!
# Preprocessed image PD_502.png saved successfully from PD folder!
# Preprocessed image PD_503.png saved successfully from PD folder!
# Preprocessed image PD_504.png saved successfully from PD folder!
# Preprocessed image PD_505.png saved successfully from PD folder!
# Preprocessed image PD_506.png saved successfully from PD folder!
# Preprocessed image PD_507.png saved successfully from PD folder!
# Preprocessed image PD_508.png saved successfully from PD folder!
# Preprocessed image PD_509.png saved successfully from PD folder!
# Preprocessed image PD_510.png saved successfully from PD folder!
# Preprocessed image PD_511.png saved successfully from PD folder!
# Preprocessed image PD_512.png saved successfully from PD folder!
# Preprocessed image PD_513.png saved successfully from PD folder!
# Preprocessed image PD_514.png saved successfully from PD folder!
# Preprocessed image PD_515.png saved successfully from PD folder!
# Preprocessed image PD_516.png saved successfully from PD folder!
# Preprocessed image PD_517.png saved successfully from PD folder!
# Preprocessed image PD_518.png saved successfully from PD folder!
# Preprocessed image PD_519.png saved successfully from PD folder!
# Preprocessed image PD_520.png saved successfully from PD folder!
# Preprocessed image PD_521.png saved successfully from PD folder!
# Preprocessed image PD_522.png saved successfully from PD folder!
# Preprocessed image PD_523.png saved successfully from PD folder!
# Preprocessed image PD_524.png saved successfully from PD folder!
# Preprocessed image PD_525.png saved successfully from PD folder!
# Preprocessed image PD_526.png saved successfully from PD folder!
# Preprocessed image PD_527.png saved successfully from PD folder!
# Preprocessed image PD_528.png saved successfully from PD folder!
# Preprocessed image PD_529.png saved successfully from PD folder!
# Preprocessed image PD_530.png saved successfully from PD folder!
# Preprocessed image PD_531.png saved successfully from PD folder!
# Preprocessed image PD_532.png saved successfully from PD folder!
# Preprocessed image PD_533.png saved successfully from PD folder!
# Preprocessed image PD_534.png saved successfully from PD folder!
# Preprocessed image PD_535.png saved successfully from PD folder!
# Preprocessed image PD_536.png saved successfully from PD folder!
# Preprocessed image PD_537.png saved successfully from PD folder!
# Preprocessed image PD_538.png saved successfully from PD folder!
# Preprocessed image PD_539.png saved successfully from PD folder!
# Preprocessed image PD_540.png saved successfully from PD folder!
# Preprocessed image PD_541.png saved successfully from PD folder!
# Preprocessed image PD_542.png saved successfully from PD folder!
# Preprocessed image PD_543.png saved successfully from PD folder!
# Preprocessed image PD_544.png saved successfully from PD folder!
# Preprocessed image PD_545.png saved successfully from PD folder!
# Preprocessed image PD_546.png saved successfully from PD folder!
# Preprocessed image PD_547.png saved successfully from PD folder!
# Preprocessed image PD_548.png saved successfully from PD folder!
# Preprocessed image PD_549.png saved successfully from PD folder!
# Preprocessed image PD_550.png saved successfully from PD folder!
# Preprocessed image PD_551.png saved successfully from PD folder!
# Preprocessed image PD_552.png saved successfully from PD folder!
# Preprocessed image PD_553.png saved successfully from PD folder!
# Preprocessed image PD_554.png saved successfully from PD folder!
# Preprocessed image PD_555.png saved successfully from PD folder!
# Preprocessed image PD_556.png saved successfully from PD folder!
# Preprocessed image PD_557.png saved successfully from PD folder!
# Preprocessed image PD_558.png saved successfully from PD folder!
# Preprocessed image PD_559.png saved successfully from PD folder!
# Preprocessed image PD_560.png saved successfully from PD folder!
# Preprocessed image PD_561.png saved successfully from PD folder!
# Preprocessed image PD_562.png saved successfully from PD folder!
# Preprocessed image PD_563.png saved successfully from PD folder!
# Preprocessed image PD_564.png saved successfully from PD folder!
# Preprocessed image PD_565.png saved successfully from PD folder!
# Preprocessed image PD_566.png saved successfully from PD folder!
# Preprocessed image PD_567.png saved successfully from PD folder!
# Preprocessed image PD_568.png saved successfully from PD folder!
# Preprocessed image PD_569.png saved successfully from PD folder!
# Preprocessed image PD_570.png saved successfully from PD folder!
# Preprocessed image PD_571.png saved successfully from PD folder!
# Preprocessed image PD_572.png saved successfully from PD folder!
# Preprocessed image PD_573.png saved successfully from PD folder!
# Preprocessed image PD_574.png saved successfully from PD folder!
# Preprocessed image PD_575.png saved successfully from PD folder!
# Preprocessed image PD_576.png saved successfully from PD folder!
# Preprocessed image PD_577.png saved successfully from PD folder!
# Preprocessed image PD_578.png saved successfully from PD folder!
# Preprocessed image PD_579.png saved successfully from PD folder!
# Preprocessed image PD_580.png saved successfully from PD folder!
# Preprocessed image PD_581.png saved successfully from PD folder!
# Preprocessed image PD_582.png saved successfully from PD folder!
# Preprocessed image PD_583.png saved successfully from PD folder!
# Preprocessed image PD_584.png saved successfully from PD folder!
# Preprocessed image PD_585.png saved successfully from PD folder!
# Preprocessed image PD_586.png saved successfully from PD folder!
# Preprocessed image PD_587.png saved successfully from PD folder!
# Preprocessed image PD_588.png saved successfully from PD folder!
# Preprocessed image PD_589.png saved successfully from PD folder!
# Preprocessed image PD_590.png saved successfully from PD folder!
# Preprocessed image PD_591.png saved successfully from PD folder!
# Preprocessed image PD_592.png saved successfully from PD folder!
# Preprocessed image PD_593.png saved successfully from PD folder!
# Preprocessed image PD_594.png saved successfully from PD folder!
# Preprocessed image PD_595.png saved successfully from PD folder!
# Preprocessed image PD_596.png saved successfully from PD folder!
# Preprocessed image PD_597.png saved successfully from PD folder!
# Preprocessed image PD_598.png saved successfully from PD folder!
# Preprocessed image PD_599.png saved successfully from PD folder!
# Preprocessed image PD_600.png saved successfully from PD folder!
# Preprocessed image PD_601.png saved successfully from PD folder!
# Preprocessed image PD_602.png saved successfully from PD folder!
# Preprocessed image PD_603.png saved successfully from PD folder!
# Preprocessed image PD_604.png saved successfully from PD folder!
# Preprocessed image PD_605.png saved successfully from PD folder!
# Preprocessed image PD_606.png saved successfully from PD folder!
# Preprocessed image PD_607.png saved successfully from PD folder!
# Preprocessed image PD_608.png saved successfully from PD folder!
# Preprocessed image PD_609.png saved successfully from PD folder!
# Preprocessed image PD_610.png saved successfully from PD folder!
# Preprocessed image PD_611.png saved successfully from PD folder!
# Preprocessed image PD_612.png saved successfully from PD folder!
# Preprocessed image PD_613.png saved successfully from PD folder!
# Preprocessed image PD_614.png saved successfully from PD folder!
# Preprocessed image PD_615.png saved successfully from PD folder!
# Preprocessed image PD_616.png saved successfully from PD folder!
# Preprocessed image PD_617.png saved successfully from PD folder!
# Preprocessed image PD_618.png saved successfully from PD folder!
# Preprocessed image PD_619.png saved successfully from PD folder!
# Preprocessed image PD_620.png saved successfully from PD folder!
# Preprocessed image PD_621.png saved successfully from PD folder!
# Preprocessed image PD_622.png saved successfully from PD folder!
# Preprocessed image PD_623.png saved successfully from PD folder!
# Preprocessed image PD_624.png saved successfully from PD folder!
# Preprocessed image PD_625.png saved successfully from PD folder!
# Preprocessed image PD_626.png saved successfully from PD folder!
# Preprocessed image PD_627.png saved successfully from PD folder!
# Preprocessed image PD_628.png saved successfully from PD folder!
# Preprocessed image PD_629.png saved successfully from PD folder!
# Preprocessed image PD_630.png saved successfully from PD folder!
# Preprocessed image PD_631.png saved successfully from PD folder!
# Preprocessed image PD_632.png saved successfully from PD folder!
# Preprocessed image PD_633.png saved successfully from PD folder!
# Preprocessed image PD_634.png saved successfully from PD folder!
# Preprocessed image PD_635.png saved successfully from PD folder!
# Preprocessed image PD_636.png saved successfully from PD folder!
# Preprocessed image PD_637.png saved successfully from PD folder!
# Preprocessed image PD_638.png saved successfully from PD folder!
# Preprocessed image PD_639.png saved successfully from PD folder!
# Preprocessed image PD_640.png saved successfully from PD folder!
# Preprocessed image PD_641.png saved successfully from PD folder!
# Preprocessed image PD_642.png saved successfully from PD folder!
# Preprocessed image PD_643.png saved successfully from PD folder!
# Preprocessed image PD_644.png saved successfully from PD folder!
# Preprocessed image PD_645.png saved successfully from PD folder!
# Preprocessed image PD_646.png saved successfully from PD folder!
# Preprocessed image PD_647.png saved successfully from PD folder!
# Preprocessed image PD_648.png saved successfully from PD folder!
# Preprocessed image PD_649.png saved successfully from PD folder!
# Preprocessed image PD_650.png saved successfully from PD folder!
# Preprocessed image PD_651.png saved successfully from PD folder!
# Preprocessed image PD_652.png saved successfully from PD folder!
# Preprocessed image PD_653.png saved successfully from PD folder!
# Preprocessed image PD_654.png saved successfully from PD folder!
# Preprocessed image PD_655.png saved successfully from PD folder!
# Preprocessed image PD_656.png saved successfully from PD folder!
# Preprocessed image PD_657.png saved successfully from PD folder!
# Preprocessed image PD_658.png saved successfully from PD folder!
# Preprocessed image PD_659.png saved successfully from PD folder!
# Preprocessed image PD_660.png saved successfully from PD folder!
# Preprocessed image PD_661.png saved successfully from PD folder!
# Preprocessed image PD_662.png saved successfully from PD folder!
# Preprocessed image PD_663.png saved successfully from PD folder!
# Preprocessed image PD_664.png saved successfully from PD folder!
# Preprocessed image PD_665.png saved successfully from PD folder!
# Preprocessed image PD_666.png saved successfully from PD folder!
# Preprocessed image PD_667.png saved successfully from PD folder!
# Preprocessed image PD_668.png saved successfully from PD folder!
# Preprocessed image PD_669.png saved successfully from PD folder!
# Preprocessed image PD_670.png saved successfully from PD folder!
# Preprocessed image PD_671.png saved successfully from PD folder!
# Preprocessed image PD_672.png saved successfully from PD folder!
# Preprocessed image PD_673.png saved successfully from PD folder!
# Preprocessed image PD_674.png saved successfully from PD folder!
# Preprocessed image PD_675.png saved successfully from PD folder!
# Preprocessed image PD_676.png saved successfully from PD folder!
# Preprocessed image PD_677.png saved successfully from PD folder!
# Preprocessed image PD_678.png saved successfully from PD folder!
# Preprocessed image PD_679.png saved successfully from PD folder!
# Preprocessed image PD_680.png saved successfully from PD folder!
# Preprocessed image PD_681.png saved successfully from PD folder!
# Preprocessed image PD_682.png saved successfully from PD folder!
# Preprocessed image PD_683.png saved successfully from PD folder!
# Preprocessed image PD_684.png saved successfully from PD folder!
# Preprocessed image PD_685.png saved successfully from PD folder!
# Preprocessed image PD_686.png saved successfully from PD folder!
# Preprocessed image PD_687.png saved successfully from PD folder!
# Preprocessed image PD_688.png saved successfully from PD folder!
# Preprocessed image PD_689.png saved successfully from PD folder!
# Preprocessed image PD_690.png saved successfully from PD folder!
# Preprocessed image PD_691.png saved successfully from PD folder!
# Preprocessed image PD_692.png saved successfully from PD folder!
# Preprocessed image PD_693.png saved successfully from PD folder!
# Preprocessed image PD_694.png saved successfully from PD folder!
# Preprocessed image PD_695.png saved successfully from PD folder!
# Preprocessed image PD_696.png saved successfully from PD folder!
# Preprocessed image PD_697.png saved successfully from PD folder!
# Preprocessed image PD_698.png saved successfully from PD folder!
# Preprocessed image PD_699.png saved successfully from PD folder!
# Preprocessed image PD_700.png saved successfully from PD folder!
# Preprocessed image PD_701.png saved successfully from PD folder!
# Preprocessed image PD_702.png saved successfully from PD folder!
# Preprocessed image PD_703.png saved successfully from PD folder!
# Preprocessed image PD_704.png saved successfully from PD folder!
# Preprocessed image PD_705.png saved successfully from PD folder!
# Preprocessed image PD_706.png saved successfully from PD folder!
# Preprocessed image PD_707.png saved successfully from PD folder!
# Preprocessed image PD_708.png saved successfully from PD folder!
# Preprocessed image PD_709.png saved successfully from PD folder!
# Preprocessed image PD_710.png saved successfully from PD folder!
# Preprocessed image PD_711.png saved successfully from PD folder!
# Preprocessed image PD_712.png saved successfully from PD folder!
# Preprocessed image PD_713.png saved successfully from PD folder!
# Preprocessed image PD_714.png saved successfully from PD folder!
# Preprocessed image PD_715.png saved successfully from PD folder!
# Preprocessed image PD_716.png saved successfully from PD folder!
# Preprocessed image PD_717.png saved successfully from PD folder!
# Preprocessed image PD_718.png saved successfully from PD folder!
# Preprocessed image PD_719.png saved successfully from PD folder!
# Preprocessed image PD_720.png saved successfully from PD folder!
# Preprocessed image PD_721.png saved successfully from PD folder!
# Preprocessed image PD_722.png saved successfully from PD folder!
# Preprocessed image PD_723.png saved successfully from PD folder!
# Preprocessed image PD_724.png saved successfully from PD folder!
# Preprocessed image PD_725.png saved successfully from PD folder!
# Preprocessed image PD_726.png saved successfully from PD folder!
# Preprocessed image PD_727.png saved successfully from PD folder!
# Preprocessed image PD_728.png saved successfully from PD folder!
# Preprocessed image PD_729.png saved successfully from PD folder!
# Preprocessed image PD_730.png saved successfully from PD folder!
# Preprocessed image PD_731.png saved successfully from PD folder!
# Preprocessed image PD_732.png saved successfully from PD folder!
# Preprocessed image PD_733.png saved successfully from PD folder!
# Preprocessed image PD_734.png saved successfully from PD folder!
# Preprocessed image PD_735.png saved successfully from PD folder!
# Preprocessed image PD_736.png saved successfully from PD folder!
# Preprocessed image PD_737.png saved successfully from PD folder!
# Preprocessed image PD_738.png saved successfully from PD folder!
# Preprocessed image PD_739.png saved successfully from PD folder!
# Preprocessed image PD_740.png saved successfully from PD folder!
# Preprocessed image PD_741.png saved successfully from PD folder!
# Preprocessed image PD_742.png saved successfully from PD folder!
# Preprocessed image PD_743.png saved successfully from PD folder!
# Preprocessed image PD_744.png saved successfully from PD folder!
# Preprocessed image PD_745.png saved successfully from PD folder!
# Preprocessed image PD_746.png saved successfully from PD folder!
# Preprocessed image PD_747.png saved successfully from PD folder!
# Preprocessed image PD_748.png saved successfully from PD folder!
# Preprocessed image PD_749.png saved successfully from PD folder!
# Preprocessed image PD_750.png saved successfully from PD folder!
# Preprocessed image PD_751.png saved successfully from PD folder!
# Preprocessed image PD_752.png saved successfully from PD folder!
# Preprocessed image PD_753.png saved successfully from PD folder!
# Preprocessed image PD_754.png saved successfully from PD folder!
# Preprocessed image PD_755.png saved successfully from PD folder!
# Preprocessed image PD_756.png saved successfully from PD folder!
# Preprocessed image PD_757.png saved successfully from PD folder!
# Preprocessed image PD_758.png saved successfully from PD folder!
# Preprocessed image PD_759.png saved successfully from PD folder!
# Preprocessed image PD_760.png saved successfully from PD folder!
# Preprocessed image PD_761.png saved successfully from PD folder!
# Preprocessed image PD_762.png saved successfully from PD folder!
# Preprocessed image PD_763.png saved successfully from PD folder!
# Preprocessed image PD_764.png saved successfully from PD folder!
# Preprocessed image PD_765.png saved successfully from PD folder!
# Preprocessed image PD_766.png saved successfully from PD folder!
# Preprocessed image PD_767.png saved successfully from PD folder!
# Preprocessed image PD_768.png saved successfully from PD folder!
# Preprocessed image PD_769.png saved successfully from PD folder!
# Preprocessed image PD_770.png saved successfully from PD folder!
# Preprocessed image PD_771.png saved successfully from PD folder!
# Preprocessed image PD_772.png saved successfully from PD folder!
# Preprocessed image PD_773.png saved successfully from PD folder!
# Preprocessed image PD_774.png saved successfully from PD folder!
# Preprocessed image PD_775.png saved successfully from PD folder!
# Preprocessed image PD_776.png saved successfully from PD folder!
# Preprocessed image PD_777.png saved successfully from PD folder!
# Preprocessed image PD_778.png saved successfully from PD folder!
# Preprocessed image PD_779.png saved successfully from PD folder!
# Preprocessed image PD_780.png saved successfully from PD folder!
# Preprocessed image PD_781.png saved successfully from PD folder!
# Preprocessed image PD_782.png saved successfully from PD folder!
# Preprocessed image PD_783.png saved successfully from PD folder!
# Preprocessed image PD_784.png saved successfully from PD folder!
# Preprocessed image PD_785.png saved successfully from PD folder!
# Preprocessed image PD_786.png saved successfully from PD folder!
# Preprocessed image PD_787.png saved successfully from PD folder!
# Preprocessed image PD_788.png saved successfully from PD folder!
# Preprocessed image PD_789.png saved successfully from PD folder!
# Preprocessed image PD_790.png saved successfully from PD folder!
# Preprocessed image PD_791.png saved successfully from PD folder!
# Preprocessed image PD_792.png saved successfully from PD folder!
# Preprocessed image PD_793.png saved successfully from PD folder!
# Preprocessed image PD_794.png saved successfully from PD folder!
# Preprocessed image PD_795.png saved successfully from PD folder!
# Preprocessed image PD_796.png saved successfully from PD folder!
# Preprocessed image PD_797.png saved successfully from PD folder!
# Preprocessed image PD_798.png saved successfully from PD folder!
# Preprocessed image PD_799.png saved successfully from PD folder!
# Preprocessed image PD_800.png saved successfully from PD folder!
# Preprocessed image PD_801.png saved successfully from PD folder!
# Preprocessed image PD_802.png saved successfully from PD folder!
# Preprocessed image PD_803.png saved successfully from PD folder!
# Preprocessed image PD_804.png saved successfully from PD folder!
# Preprocessed image PD_805.png saved successfully from PD folder!
# Preprocessed image PD_806.png saved successfully from PD folder!
# Preprocessed image PD_807.png saved successfully from PD folder!
# Preprocessed image PD_808.png saved successfully from PD folder!
# Preprocessed image PD_809.png saved successfully from PD folder!
# Preprocessed image PD_810.png saved successfully from PD folder!
# Preprocessed image PD_811.png saved successfully from PD folder!
# Preprocessed image PD_812.png saved successfully from PD folder!
# Preprocessed image PD_813.png saved successfully from PD folder!
# Preprocessed image PD_814.png saved successfully from PD folder!
# Preprocessed image PD_815.png saved successfully from PD folder!
# Preprocessed image PD_816.png saved successfully from PD folder!
# Preprocessed image PD_817.png saved successfully from PD folder!
# Preprocessed image PD_818.png saved successfully from PD folder!
# Preprocessed image PD_819.png saved successfully from PD folder!
# Preprocessed image PD_820.png saved successfully from PD folder!
# Preprocessed image PD_821.png saved successfully from PD folder!
# Preprocessed image PD_822.png saved successfully from PD folder!
# Preprocessed image PD_823.png saved successfully from PD folder!
# Preprocessed image PD_824.png saved successfully from PD folder!
# Preprocessed image PD_825.png saved successfully from PD folder!
# Preprocessed image PD_826.png saved successfully from PD folder!
# Preprocessed image PD_827.png saved successfully from PD folder!
# Preprocessed image PD_828.png saved successfully from PD folder!
# Preprocessed image PD_829.png saved successfully from PD folder!
# Preprocessed image PD_830.png saved successfully from PD folder!
# Preprocessed image PD_831.png saved successfully from PD folder!
# Preprocessed image PD_832.png saved successfully from PD folder!
# Preprocessed image PD_833.png saved successfully from PD folder!
# Preprocessed image PD_834.png saved successfully from PD folder!
# Preprocessed image PD_835.png saved successfully from PD folder!
# Preprocessed image PD_836.png saved successfully from PD folder!
# Preprocessed image PD_837.png saved successfully from PD folder!
# Preprocessed image PD_838.png saved successfully from PD folder!
# Preprocessed image PD_839.png saved successfully from PD folder!
# Preprocessed image PD_840.png saved successfully from PD folder!
# Preprocessed image PD_841.png saved successfully from PD folder!
# Preprocessed image PD_842.png saved successfully from PD folder!
# Preprocessed image PD_843.png saved successfully from PD folder!
# Preprocessed image PD_844.png saved successfully from PD folder!
# Preprocessed image PD_845.png saved successfully from PD folder!
# Preprocessed image PD_846.png saved successfully from PD folder!
# Preprocessed image PD_847.png saved successfully from PD folder!
# Preprocessed image PD_848.png saved successfully from PD folder!
# Preprocessed image PD_849.png saved successfully from PD folder!
# Preprocessed image PD_850.png saved successfully from PD folder!
# Preprocessed image PD_851.png saved successfully from PD folder!
# Preprocessed image PD_852.png saved successfully from PD folder!
# Preprocessed image PD_853.png saved successfully from PD folder!
# Preprocessed image PD_854.png saved successfully from PD folder!
# Preprocessed image PD_855.png saved successfully from PD folder!
# Preprocessed image PD_856.png saved successfully from PD folder!
# Preprocessed image PD_857.png saved successfully from PD folder!
# Preprocessed image PD_858.png saved successfully from PD folder!
# Preprocessed image PD_859.png saved successfully from PD folder!
# Preprocessed image PD_860.png saved successfully from PD folder!
# Preprocessed image PD_861.png saved successfully from PD folder!
# Preprocessed image PD_862.png saved successfully from PD folder!
# Preprocessed image PD_863.png saved successfully from PD folder!
# Preprocessed image PD_864.png saved successfully from PD folder!
# Preprocessed image PD_865.png saved successfully from PD folder!
# Preprocessed image PD_866.png saved successfully from PD folder!
# Preprocessed image PD_867.png saved successfully from PD folder!
# Preprocessed image PD_868.png saved successfully from PD folder!
# Preprocessed image PD_869.png saved successfully from PD folder!
# Preprocessed image PD_870.png saved successfully from PD folder!
# Preprocessed image PD_871.png saved successfully from PD folder!
# Preprocessed image PD_872.png saved successfully from PD folder!
# Preprocessed image PD_873.png saved successfully from PD folder!
# Preprocessed image PD_874.png saved successfully from PD folder!
# Preprocessed image PD_875.png saved successfully from PD folder!
# Preprocessed image PD_876.png saved successfully from PD folder!
# Preprocessed image PD_877.png saved successfully from PD folder!
# Preprocessed image PD_878.png saved successfully from PD folder!
# Preprocessed image PD_879.png saved successfully from PD folder!
# Preprocessed image PD_880.png saved successfully from PD folder!
# Preprocessed image PD_881.png saved successfully from PD folder!
# Preprocessed image PD_882.png saved successfully from PD folder!
# Preprocessed image PD_883.png saved successfully from PD folder!
# Preprocessed image PD_884.png saved successfully from PD folder!
# Preprocessed image PD_885.png saved successfully from PD folder!
# Preprocessed image PD_886.png saved successfully from PD folder!
# Preprocessed image PD_887.png saved successfully from PD folder!
# Preprocessed image PD_888.png saved successfully from PD folder!
# Preprocessed image PD_889.png saved successfully from PD folder!
# Preprocessed image PD_890.png saved successfully from PD folder!
# Preprocessed image PD_891.png saved successfully from PD folder!
# Preprocessed image PD_892.png saved successfully from PD folder!
# Preprocessed image PD_893.png saved successfully from PD folder!
# Preprocessed image PD_894.png saved successfully from PD folder!
# Preprocessed image PD_895.png saved successfully from PD folder!
# Preprocessed image PD_896.png saved successfully from PD folder!
# Preprocessed image PD_897.png saved successfully from PD folder!
# Preprocessed image PD_898.png saved successfully from PD folder!
# Preprocessed image PD_899.png saved successfully from PD folder!
# Preprocessed image PD_900.png saved successfully from PD folder!
# Preprocessed image PD_901.png saved successfully from PD folder!
# Preprocessed image PD_902.png saved successfully from PD folder!
# Preprocessed image PD_903.png saved successfully from PD folder!
# Preprocessed image PD_904.png saved successfully from PD folder!
# Preprocessed image PD_905.png saved successfully from PD folder!
# Preprocessed image PD_906.png saved successfully from PD folder!

# %%
for i in range(1, 177):
    filename = f'normal_{i:03}.png'
    input_image = Image.open(os.path.join(input_path_normal, filename)).convert('L')

    image_array = np.asarray(input_image)

    if np.std(image_array) == 0:
        print(f"Warning: Standard deviation of image {filename} is 0, skipping normalization.")
        continue

    image_array = (image_array - image_array.mean()) / np.std(image_array)

    resized_image = ndimage.zoom(image_array, (0.5, 0.5), mode='constant', order=1)
    blurred_image = ndimage.gaussian_filter(resized_image, sigma=1)

    if output_format == "PNG":
        scaled_image = (blurred_image * 255).astype(np.uint8)
        preprocessed_image = Image.fromarray(scaled_image)
        preprocessed_image.save(os.path.join(output_path, filename))
    elif output_format == "TIFF":
        imsave(os.path.join(output_path, filename), blurred_image.astype(np.float32))
    else:
        print(f"Invalid output format specified: {output_format}. Please choose 'PNG' or 'TIFF'.")

    print(f"Preprocessed image {filename} saved successfully from Normal folder!")

print("Preprocessing complete!")
# Out:
# Preprocessed image normal_001.png saved successfully from Normal folder!
# Preprocessed image normal_002.png saved successfully from Normal folder!
# Preprocessed image normal_003.png saved successfully from Normal folder!
# Preprocessed image normal_004.png saved successfully from Normal folder!
# Preprocessed image normal_005.png saved successfully from Normal folder!
# Preprocessed image normal_006.png saved successfully from Normal folder!
# Preprocessed image normal_007.png saved successfully from Normal folder!
# Preprocessed image normal_008.png saved successfully from Normal folder!
# Preprocessed image normal_009.png saved successfully from Normal folder!
# Preprocessed image normal_010.png saved successfully from Normal folder!
# Preprocessed image normal_011.png saved successfully from Normal folder!
# Preprocessed image normal_012.png saved successfully from Normal folder!
# Preprocessed image normal_013.png saved successfully from Normal folder!
# Preprocessed image normal_014.png saved successfully from Normal folder!
# Preprocessed image normal_015.png saved successfully from Normal folder!
# Preprocessed image normal_016.png saved successfully from Normal folder!
# Preprocessed image normal_017.png saved successfully from Normal folder!
# Preprocessed image normal_018.png saved successfully from Normal folder!
# Preprocessed image normal_019.png saved successfully from Normal folder!
# Preprocessed image normal_020.png saved successfully from Normal folder!
# Preprocessed image normal_021.png saved successfully from Normal folder!
# Preprocessed image normal_022.png saved successfully from Normal folder!
# Preprocessed image normal_023.png saved successfully from Normal folder!
# Preprocessed image normal_024.png saved successfully from Normal folder!
# Preprocessed image normal_025.png saved successfully from Normal folder!
# Preprocessed image normal_026.png saved successfully from Normal folder!
# Preprocessed image normal_027.png saved successfully from Normal folder!
# Preprocessed image normal_028.png saved successfully from Normal folder!
# Preprocessed image normal_029.png saved successfully from Normal folder!
# Preprocessed image normal_030.png saved successfully from Normal folder!
# Preprocessed image normal_031.png saved successfully from Normal folder!
# Preprocessed image normal_032.png saved successfully from Normal folder!
# Preprocessed image normal_033.png saved successfully from Normal folder!
# Preprocessed image normal_034.png saved successfully from Normal folder!
# Preprocessed image normal_035.png saved successfully from Normal folder!
# Preprocessed image normal_036.png saved successfully from Normal folder!
# Preprocessed image normal_037.png saved successfully from Normal folder!
# Preprocessed image normal_038.png saved successfully from Normal folder!
# Preprocessed image normal_039.png saved successfully from Normal folder!
# Preprocessed image normal_040.png saved successfully from Normal folder!
# Preprocessed image normal_041.png saved successfully from Normal folder!
# Preprocessed image normal_042.png saved successfully from Normal folder!
# Preprocessed image normal_043.png saved successfully from Normal folder!
# Preprocessed image normal_044.png saved successfully from Normal folder!
# Preprocessed image normal_045.png saved successfully from Normal folder!
# Preprocessed image normal_046.png saved successfully from Normal folder!
# Preprocessed image normal_047.png saved successfully from Normal folder!
# Preprocessed image normal_048.png saved successfully from Normal folder!
# Preprocessed image normal_049.png saved successfully from Normal folder!
# Preprocessed image normal_050.png saved successfully from Normal folder!
# Preprocessed image normal_051.png saved successfully from Normal folder!
# Preprocessed image normal_052.png saved successfully from Normal folder!
# Preprocessed image normal_053.png saved successfully from Normal folder!
# Preprocessed image normal_054.png saved successfully from Normal folder!
# Preprocessed image normal_055.png saved successfully from Normal folder!
# Preprocessed image normal_056.png saved successfully from Normal folder!
# Preprocessed image normal_057.png saved successfully from Normal folder!
# Preprocessed image normal_058.png saved successfully from Normal folder!
# Preprocessed image normal_059.png saved successfully from Normal folder!
# Preprocessed image normal_060.png saved successfully from Normal folder!
# Preprocessed image normal_061.png saved successfully from Normal folder!
# Preprocessed image normal_062.png saved successfully from Normal folder!
# Preprocessed image normal_063.png saved successfully from Normal folder!
# Preprocessed image normal_064.png saved successfully from Normal folder!
# Preprocessed image normal_065.png saved successfully from Normal folder!
# Preprocessed image normal_066.png saved successfully from Normal folder!
# Preprocessed image normal_067.png saved successfully from Normal folder!
# Preprocessed image normal_068.png saved successfully from Normal folder!
# Preprocessed image normal_069.png saved successfully from Normal folder!
# Preprocessed image normal_070.png saved successfully from Normal folder!
# Preprocessed image normal_071.png saved successfully from Normal folder!
# Preprocessed image normal_072.png saved successfully from Normal folder!
# Preprocessed image normal_073.png saved successfully from Normal folder!
# Preprocessed image normal_074.png saved successfully from Normal folder!
# Preprocessed image normal_075.png saved successfully from Normal folder!
# Preprocessed image normal_076.png saved successfully from Normal folder!
# Preprocessed image normal_077.png saved successfully from Normal folder!
# Preprocessed image normal_078.png saved successfully from Normal folder!
# Preprocessed image normal_079.png saved successfully from Normal folder!
# Preprocessed image normal_080.png saved successfully from Normal folder!
# Preprocessed image normal_081.png saved successfully from Normal folder!
# Preprocessed image normal_082.png saved successfully from Normal folder!
# Preprocessed image normal_083.png saved successfully from Normal folder!
# Preprocessed image normal_084.png saved successfully from Normal folder!
# Preprocessed image normal_085.png saved successfully from Normal folder!
# Preprocessed image normal_086.png saved successfully from Normal folder!
# Preprocessed image normal_087.png saved successfully from Normal folder!
# Preprocessed image normal_088.png saved successfully from Normal folder!
# Preprocessed image normal_089.png saved successfully from Normal folder!
# Preprocessed image normal_090.png saved successfully from Normal folder!
# Preprocessed image normal_091.png saved successfully from Normal folder!
# Preprocessed image normal_092.png saved successfully from Normal folder!
# Preprocessed image normal_093.png saved successfully from Normal folder!
# Preprocessed image normal_094.png saved successfully from Normal folder!
# Preprocessed image normal_095.png saved successfully from Normal folder!
# Preprocessed image normal_096.png saved successfully from Normal folder!
# Preprocessed image normal_097.png saved successfully from Normal folder!
# Preprocessed image normal_098.png saved successfully from Normal folder!
# Preprocessed image normal_099.png saved successfully from Normal folder!
# Preprocessed image normal_100.png saved successfully from Normal folder!
# Preprocessed image normal_101.png saved successfully from Normal folder!
# Preprocessed image normal_102.png saved successfully from Normal folder!
# Preprocessed image normal_103.png saved successfully from Normal folder!
# Preprocessed image normal_104.png saved successfully from Normal folder!
# Preprocessed image normal_105.png saved successfully from Normal folder!
# Preprocessed image normal_106.png saved successfully from Normal folder!
# Preprocessed image normal_107.png saved successfully from Normal folder!
# Preprocessed image normal_108.png saved successfully from Normal folder!
# Preprocessed image normal_109.png saved successfully from Normal folder!
# Preprocessed image normal_110.png saved successfully from Normal folder!
# Preprocessed image normal_111.png saved successfully from Normal folder!
# Preprocessed image normal_112.png saved successfully from Normal folder!
# Preprocessed image normal_113.png saved successfully from Normal folder!
# Preprocessed image normal_114.png saved successfully from Normal folder!
# Preprocessed image normal_115.png saved successfully from Normal folder!
# Preprocessed image normal_116.png saved successfully from Normal folder!
# Preprocessed image normal_117.png saved successfully from Normal folder!
# Preprocessed image normal_118.png saved successfully from Normal folder!
# Preprocessed image normal_119.png saved successfully from Normal folder!
# Preprocessed image normal_120.png saved successfully from Normal folder!
# Preprocessed image normal_121.png saved successfully from Normal folder!
# Preprocessed image normal_122.png saved successfully from Normal folder!
# Preprocessed image normal_123.png saved successfully from Normal folder!
# Preprocessed image normal_124.png saved successfully from Normal folder!
# Preprocessed image normal_125.png saved successfully from Normal folder!
# Preprocessed image normal_126.png saved successfully from Normal folder!
# Preprocessed image normal_127.png saved successfully from Normal folder!
# Preprocessed image normal_128.png saved successfully from Normal folder!
# Preprocessed image normal_129.png saved successfully from Normal folder!
# Preprocessed image normal_130.png saved successfully from Normal folder!
# Preprocessed image normal_131.png saved successfully from Normal folder!
# Preprocessed image normal_132.png saved successfully from Normal folder!
# Preprocessed image normal_133.png saved successfully from Normal folder!
# Preprocessed image normal_134.png saved successfully from Normal folder!
# Preprocessed image normal_135.png saved successfully from Normal folder!
# Preprocessed image normal_136.png saved successfully from Normal folder!
# Preprocessed image normal_137.png saved successfully from Normal folder!
# Preprocessed image normal_138.png saved successfully from Normal folder!
# Preprocessed image normal_139.png saved successfully from Normal folder!
# Preprocessed image normal_140.png saved successfully from Normal folder!
# Preprocessed image normal_141.png saved successfully from Normal folder!
# Preprocessed image normal_142.png saved successfully from Normal folder!
# Preprocessed image normal_143.png saved successfully from Normal folder!
# Preprocessed image normal_144.png saved successfully from Normal folder!
# Preprocessed image normal_145.png saved successfully from Normal folder!
# Preprocessed image normal_146.png saved successfully from Normal folder!
# Preprocessed image normal_147.png saved successfully from Normal folder!
# Preprocessed image normal_148.png saved successfully from Normal folder!
# Preprocessed image normal_149.png saved successfully from Normal folder!
# Preprocessed image normal_150.png saved successfully from Normal folder!
# Preprocessed image normal_151.png saved successfully from Normal folder!
# Preprocessed image normal_152.png saved successfully from Normal folder!
# Preprocessed image normal_153.png saved successfully from Normal folder!
# Preprocessed image normal_154.png saved successfully from Normal folder!
# Preprocessed image normal_155.png saved successfully from Normal folder!
# Preprocessed image normal_156.png saved successfully from Normal folder!
# Preprocessed image normal_157.png saved successfully from Normal folder!
# Preprocessed image normal_158.png saved successfully from Normal folder!
# Preprocessed image normal_159.png saved successfully from Normal folder!
# Preprocessed image normal_160.png saved successfully from Normal folder!
# Preprocessed image normal_161.png saved successfully from Normal folder!
# Preprocessed image normal_162.png saved successfully from Normal folder!
# Preprocessed image normal_163.png saved successfully from Normal folder!
# Preprocessed image normal_164.png saved successfully from Normal folder!
# Preprocessed image normal_165.png saved successfully from Normal folder!
# Preprocessed image normal_166.png saved successfully from Normal folder!
# Preprocessed image normal_167.png saved successfully from Normal folder!
# Preprocessed image normal_168.png saved successfully from Normal folder!
# Preprocessed image normal_169.png saved successfully from Normal folder!
# Preprocessed image normal_170.png saved successfully from Normal folder!
# Preprocessed image normal_171.png saved successfully from Normal folder!
# Preprocessed image normal_172.png saved successfully from Normal folder!
# Preprocessed image normal_173.png saved successfully from Normal folder!
# Preprocessed image normal_174.png saved successfully from Normal folder!
# Preprocessed image normal_175.png saved successfully from Normal folder!
# Preprocessed image normal_176.png saved successfully from Normal folder!
# Preprocessing complete!
